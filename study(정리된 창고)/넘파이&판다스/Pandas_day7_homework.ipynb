# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import re

# 인스타그램 접속
driver = webdriver.Chrome()
driver.get("https://www.instagram.com/accounts/login/")
time.sleep(2)

# 로그인 작업
input_id = driver.find_elements("css selector", "#loginForm > div > div:nth-child(1) > div > label > input")[0]
input_pw = driver.find_elements("css selector","#loginForm > div > div:nth-child(2) > div > label > input")[0]
input_id.send_keys("my2006s@gmail.com")
input_pw.send_keys("dlarbtkd1!")
input_pw.submit()
time.sleep(3)

#네셔널 지오그래피 접속
driver.get("https://www.instagram.com/natgeo/")
time.sleep(2)

#카테고리 생성
national_categories = []
index_no = 0
button_count = 0
# 사진 갯수 확인 / 클릭 
photo_list = driver.find_elements("css selector","div._aagw")
photo_len = len(photo_list)
photo_list[0].click()

# %%
#네셔널 지오그래피 접속
driver.get("https://www.instagram.com/natgeo/")
time.sleep(2)

#카테고리 생성
national_categories = []
index_no = 0
button_count = 0
# 사진 갯수 확인 / 클릭 
photo_list = driver.find_elements("css selector","div._aagw")
photo_len = len(photo_list)
photo_list[0].click()

# %%
for i in range(photo_len):
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    content = soup.select("ul > div > li > div > div > div._a9zr > div._a9zs > h1")[0].text
    like = soup.select("a > span")[-2].text
    upload_time = soup.select("a > span > time")[0]['datetime'].strip()
    index_no += 1
    national_categories.append([index_no,content,like,upload_time])
    btn1 = driver.find_elements("css selector", "button> div > span > svg.x1lliihq.x1n2onr6")
    btn1[button_count].click()
    if button_count == 0:
        button_count += 1
    time.sleep(1)

# %%
national_categories = []
# Out:
# [[1,
#   "Photo by @kiliiiyuyan | I'm on assignment on the Ningaloo Reef, in the sparkling waters off Western Australia. It's one of those times when I'm actually doing what my friends think I do all the time: swimming with whale sharks and diving over reefs of red coral and giant fish. This is a fringing reef with nutrients from an offshore upwelling, which attracts everything up to Ningaloo's charismatic big three: humpbacks, whale sharks, and manta rays. Thanks to protections from UNESCO and a dedicated local community, 45,000 humpbacks migrate through each year, and you can be in the water as they cruise by or—for the adventurous—feel small swimming next to a whale shark.Follow me, @kiliiiyuyan, for more beyond the sea.",
#   '좋아요 3.5만개',
#   '2023-09-18T22:00:12.000Z'],
#  [2,
# ...

# %%
df2 = pd.DataFrame(national_categories, columns = ['순서',"내용",'좋아요','날짜'])
df2
df2.to_excel("National.xlsx",index = False)
# Out:
#     순서                                                 내용         좋아요  \
# 0    1  Photo by @kiliiiyuyan | I'm on assignment on t...   좋아요 3.5만개
# 1    2  Video by Muhammed Muheisen @mmuheisen | I capt...   좋아요 8.6만개
# 2    3  Discover more at the link in bio.The 2021 volc...   좋아요 1.9만개
# 3    4  Photo by Robert Clark @robertclarkphoto | Seve...   좋아요 6.6만개
# 4    5  Photo by @rubensalgadoescudero | A man helps h...   좋아요 9.9만개
# 5    6  Photos by Matthieu Paley @paleyphoto I Sometim...   좋아요 8.9만개
# 6    7  Photo by @beverlyjoubert | It's impossible to ...   좋아요 6.7만개
# 7    8  Photos by @acacia.johnson | It was high tide w...   좋아요 9.6만개
# 8    9  A spotless giraffe, pictured in Namibia, was s...  좋아요 21.1만개
# 9   10  Photos by @yagazieemezi | These are some of my...   좋아요 9.2만개
# 10  11  Time-lapse video by @babaktafreshi | Sound on ...  좋아요 20.5만개
# 11  12  Photo by Mattias Klum @mattiasklumofficial | A...     좋아요 6만개
#
#                           날짜
# ...

# %%
h1 > a.x1i10hfl.xjbqb8w.x6umtig.x1b1mbwd.xaqea5y.xav7gou.x9f619.x1ypdohk.xt0psk2.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x16tdsg8.x1hl2dhg.xggy1nq.x1a2a7pz._aa9_._a6hd
