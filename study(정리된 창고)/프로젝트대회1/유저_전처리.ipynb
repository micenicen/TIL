# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from tensorflow.keras.utils import to_categorical
from konlpy.tag import Okt

# %%
res = pd.read_csv('resume.csv')
res = res.sort_values('resume_seq')
res = res.set_index(['resume_seq'])
res
# Out:
#               reg_date updated_date  degree  graduate_date  hope_salary  \
# resume_seq
# U00001      2019-12-27   2020-02-01       4           2009       1500.0
# U00002      2020-04-24   2020-04-29       4           2005          0.0
# U00003      2018-02-14   2020-07-08       4           2004          0.0
# U00004      2017-10-26   2020-04-27       4           2011          0.0
# U00005      2020-03-18   2020-04-08       4           2011          0.0
# ...                ...          ...     ...            ...          ...
# U08478      2020-02-05   2020-03-31       4           2003          0.0
# U08479      2016-02-17   2020-07-15       3              0       2500.0
# U08480      2019-11-13   2020-06-24       4              0          0.0
# U08481      2020-07-09   2020-11-23       4           2015          0.0
# U08482      2020-11-29   2020-11-29       4              0          0.0
#
#             last_salary                    text_keyword job_code_seq1  \
# resume_seq
# U00001           1500.0                            디자이너   재료·화학·섬유·의복
# U00002              0.0                            디자이너   재료·화학·섬유·의복
# U00003              0.0                   남성복디자이너;TD캐주얼   재료·화학·섬유·의복
# U00004              0.0                       상품기획;영업기획   재료·화학·섬유·의복
# U00005              0.0                인사;총무;경영;MD;상품기획   재료·화학·섬유·의복
# ...                 ...                             ...           ...
# U08478           2700.0                            상품기획   재료·화학·섬유·의복
# U08479           2300.0                            디자이너   재료·화학·섬유·의복
# U08480              0.0  VMD;텍스타일디자인;섬유디자인;니트디자인;여성복디자인           디자인
# U08481           2700.0                 상품기획;머천다이저;기획MD   재료·화학·섬유·의복
# U08482              0.0     상품기획;영업MD;머천다이저;기획MD;마케팅;PR   재료·화학·섬유·의복
#
#            job_code_seq2 job_code_seq3  career_month career_job_code
# resume_seq
# U00001               NaN           NaN             0             NaN
# U00002               NaN           NaN            73     기타 공공;개인서비스
# U00003               NaN           NaN           113     섬유;봉제;가방;의류
# U00004               NaN           NaN            27     섬유;봉제;가방;의류
# U00005               NaN           NaN             0             NaN
# ...                  ...           ...           ...             ...
# U08478               NaN           NaN            60     섬유;봉제;가방;의류
# U08479               NaN           NaN            59      디자인;CAD;설계
# U08480               NaN           NaN             0             NaN
# U08481               NaN           NaN             8     섬유;봉제;가방;의류
# U08482               NaN           NaN             0             NaN
#
# [8482 rows x 12 columns]

# %%
res_mer = res.drop(['reg_date','updated_date','job_code_seq2','job_code_seq3'],axis=1)
res_mer
# Out:
#             degree  graduate_date  hope_salary  last_salary  \
# resume_seq
# U00001           4           2009       1500.0       1500.0
# U00002           4           2005          0.0          0.0
# U00003           4           2004          0.0          0.0
# U00004           4           2011          0.0          0.0
# U00005           4           2011          0.0          0.0
# ...            ...            ...          ...          ...
# U08478           4           2003          0.0       2700.0
# U08479           3              0       2500.0       2300.0
# U08480           4              0          0.0          0.0
# U08481           4           2015          0.0       2700.0
# U08482           4              0          0.0          0.0
#
#                               text_keyword job_code_seq1  career_month  \
# resume_seq
# U00001                                디자이너   재료·화학·섬유·의복             0
# U00002                                디자이너   재료·화학·섬유·의복            73
# U00003                       남성복디자이너;TD캐주얼   재료·화학·섬유·의복           113
# U00004                           상품기획;영업기획   재료·화학·섬유·의복            27
# U00005                    인사;총무;경영;MD;상품기획   재료·화학·섬유·의복             0
# ...                                    ...           ...           ...
# U08478                                상품기획   재료·화학·섬유·의복            60
# U08479                                디자이너   재료·화학·섬유·의복            59
# U08480      VMD;텍스타일디자인;섬유디자인;니트디자인;여성복디자인           디자인             0
# U08481                     상품기획;머천다이저;기획MD   재료·화학·섬유·의복             8
# U08482         상품기획;영업MD;머천다이저;기획MD;마케팅;PR   재료·화학·섬유·의복             0
#
#            career_job_code
# resume_seq
# U00001                 NaN
# U00002         기타 공공;개인서비스
# U00003         섬유;봉제;가방;의류
# U00004         섬유;봉제;가방;의류
# U00005                 NaN
# ...                    ...
# U08478         섬유;봉제;가방;의류
# U08479          디자인;CAD;설계
# U08480                 NaN
# U08481         섬유;봉제;가방;의류
# U08482                 NaN
#
# [8482 rows x 8 columns]

# %%
res_mer.info()
for i in range(len(res_mer)):
    if res_mer["hope_salary"].iloc[i] == 0.:
        if res_mer["last_salary"].iloc[i] !=0.:
            res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
    elif res_mer["last_salary"].iloc[i] == 0.:
        if res_mer["hope_salary"].iloc[i] !=0.:
            res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8482 entries, U00001 to U08482
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   degree           8482 non-null   int64
#  1   graduate_date    8482 non-null   int64
#  2   hope_salary      8482 non-null   float64
#  3   last_salary      8482 non-null   float64
#  4   text_keyword     8287 non-null   object
#  5   job_code_seq1    8482 non-null   object
#  6   career_month     8482 non-null   int64
#  7   career_job_code  7724 non-null   object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 596.4+ KB
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# ...
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["last_salary"].iloc[i] = res_mer["hope_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\572712606.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_mer["hope_salary"].iloc[i] = res_mer["last_salary"].iloc[i]

# %%
res_mer['text_box'] = res_mer['text_keyword'].str.split(';')               # 텍스트 키워드 확인 
set_in = []

for i in res_mer['text_box']:
    if i is not None:
        if not isinstance(i, float):
            set_in.extend(i)

check = list(set(set_in))

# %%
check = [word.replace('MD', '기획') for word in check]        # MD라는 말을 기획으로 바꾸기

# %%
okt = Okt()
set_index = []
for i in check:
    setting = okt.nouns(i)
    set_index.extend(setting)
check = set_index

# %%
check_vc = pd.Series(check).value_counts()
check_vc2 = []
for i in check_vc.index:
    if len(i) > 1:
        check_vc2.append(i)
check_vc2
# Out:
# ['기획',
#  '영업',
#  '관리',
#  '디자인',
#  '디자이너',
#  '패션',
#  '상품',
#  '의류',
#  '매장',
#  '생산',
#  '브랜드',
#  '성복',
#  '백화점',
#  '경력',
#  '해외',
#  '남성',
#  '대리점',
#  '주얼',
#  '쥬얼',
#  '유통',
#  '마케팅',
#  '여성',
#  '개설',
#  '총괄',
#  '개발',
#  '스포츠',
#  '구매',
#  '우븐',
#  '웨어',
#  '바잉',
#  '분석',
#  '홍보',
#  '스타일',
#  '의상',
#  '업무',
#  '무역',
#  '수입',
#  '니트',
#  '잡화',
#  '소재',
#  '바이어',
#  '사업',
#  '가능',
#  '디스플레이',
#  '지원',
#  '신규',
#  '광고',
#  '아웃도어',
#  '상담',
#  '아울렛',
#  '온라인',
#  '용품',
#  '골프',
#  '부자',
#  '할인점',
#  '캐릭터',
#  '신입',
#  '쇼핑몰',
#  '프로모션',
#  '판매',
#  '다이마루',
#  '자재',
#  '패션디자이너',
#  '피팅',
#  '엠디',
#  '중국',
#  '운영',
#  '아동복',
#  '컬러',
#  '리스트',
#  '유아',
#  '로드',
#  '원단',
#  '담당',
#  '그래픽',
#  '데님',
#  '정보',
#  '편집',
#  '교육',
#  '트렌드',
#  '국내',
#  '샘플',
#  '수출입',
#  '섬유',
#  '물류',
#  '사무',
#  '오픈',
#  '핸들링',
#  '핸드백',
#  '인사',
#  '가방',
#  '상권',
#  '경영',
#  '인터넷',
#  '실장',
#  '관련',
#  '수출',
#  '품질',
#  '유니섹스',
#  '고객',
#  '전략',
#  '진행',
#  '패턴',
#  '인턴',
#  '제작',
#  '일반',
#  '일러스트',
#  '회계',
#  '인재',
#  '컨설팅',
#  '디렉터',
#  '자재관리',
#  '입출',
#  '경험',
#  '런칭',
#  '전산',
#  '티셔츠',
#  '막내',
#  '악세사리',
#  '부장',
#  '신발',
#  '업체',
#  '아동',
#  '정장',
#  '발주',
#  '가두',
#  '제휴',
#  '중국어',
#  '행사',
#  '매니저',
#  '특종',
#  '가죽',
#  '캐주얼웨어',
#  '전반',
#  '관리자',
#  '원부',
#  '본부장',
#  '일본',
#  '일본어',
#  '얼머',
#  '비주',
#  '그래픽디자인',
#  '스웨터',
#  '전략기획',
#  '조사',
#  '이징',
#  '보조',
#  '홈쇼핑',
#  '원가',
#  '매출',
#  '운송',
#  '잡지',
#  '포토샵',
#  '동복',
#  '검사',
#  '시장',
#  '컴퓨터',
#  '오프라인',
#  '정산',
#  '기술',
#  '총무',
#  '계획',
#  '작업',
#  '영어',
#  '엽업',
#  '모피',
#  '설계',
#  '전문가',
#  '메인',
#  '재발주',
#  '식품',
#  '거래처',
#  '컨텐츠',
#  '소비자',
#  '전문',
#  '손익',
#  '스트릿',
#  '전공',
#  '사원',
#  '마트',
#  '인테리어',
#  '디네',
#  '쉐터',
#  '코디',
#  '화장품',
#  '가공',
#  '면세점',
#  '영기획',
#  '피혁',
#  '재개발',
#  '등등',
#  '구두',
#  '거래',
#  '명품',
#  '채널',
#  '방송',
#  '디스',
#  '촬영',
#  '외주',
#  '점포',
#  '금융',
#  '준비',
#  '기자',
#  '환경',
#  '주얼리',
#  '통합',
#  '기업',
#  '전시',
#  '유니폼',
#  '임원',
#  '통관',
#  '커리어',
#  '개척',
#  '리테일',
#  '연구',
#  '유니',
#  '에디터',
#  '물량',
#  '색채',
#  '아이템',
#  '등산',
#  '미술',
#  '이력서',
#  '그래픽디자이너',
#  '구축',
#  '엑셀',
#  '부동산',
#  '원자재',
#  '감각',
#  '컬렉션',
#  '싱및',
#  '도식',
#  '면세',
#  '토탈',
#  '금속',
#  '대리',
#  '보험',
#  '시즌',
#  '스타',
#  '셔츠',
#  '안전',
#  '수립',
#  '노무',
#  '아우',
#  '라이프스타일',
#  '분야',
#  '연출',
#  '정규직',
#  '리서치',
#  '패럴',
#  '장비',
#  '서비스',
#  '국제',
#  '마스터',
#  '기회',
#  '란제리',
#  '행정',
#  '랜드',
#  '숙녀',
#  '열정',
#  '섬유공학',
#  '칼라',
#  '재고',
#  '관광',
#  '전시회',
#  '판촉',
#  '산업',
#  '비서',
#  '재무',
#  '성실',
#  '근무',
#  '키즈',
#  '통역',
#  '남자',
#  '뉴욕',
#  '문서',
#  '경리',
#  '세무',
#  '편집디자인',
#  '건축',
#  '예산',
#  '반도체',
#  '복캐',
#  '서류',
#  '핸드',
#  '채용',
#  '외자',
#  '피팅모델',
#  '이벤트',
#  '스토어',
#  '비쥬',
#  '본부',
#  '지사',
#  '희망',
#  '종합',
#  '자금',
#  '프린트',
#  '프로그램',
#  '요가',
#  '야구',
#  '포츠',
#  '다지',
#  '이탈리아',
#  '건설',
#  '자동차',
#  '의복',
#  '복의',
#  '노력',
#  '공간',
#  '입사',
#  '일링',
#  '임금',
#  '주니어',
#  '코스',
#  '라운딩',
#  '넥타이',
#  '모델',
#  '인력',
#  '제품디자인',
#  '회화',
#  '기능',
#  '글로벌',
#  '시장조사',
#  '축구',
#  '모자',
#  '플래쉬',
#  '언더웨어',
#  '샵마스터',
#  '운용',
#  '기능사',
#  '양말',
#  '아트웍',
#  '수트',
#  '담당자',
#  '브릭',
#  '플리',
#  '지갑',
#  '지역',
#  '쥬니어',
#  '직물',
#  '급여',
#  '마감',
#  '라벨',
#  '특판',
#  '유학',
#  '대행',
#  '교사',
#  '커머스',
#  '제약',
#  '블로그',
#  '직소',
#  '바이',
#  '부문',
#  '가맹',
#  '노사',
#  '부가세',
#  '여캐',
#  '강사',
#  '인원',
#  '주임',
#  '법인',
#  '사무직',
#  '공장',
#  '영업직',
#  '판매관리',
#  '구직',
#  '자사',
#  '레저',
#  '제어',
#  '완제',
#  '마켓',
#  '조직',
#  '운동화',
#  '패딩',
#  '서장',
#  '신사복',
#  '자산',
#  '관리사',
#  '직영',
#  '미팅',
#  '무대',
#  '단체',
#  '사이트',
#  '소매',
#  '출판',
#  '바잉및',
#  '공정',
#  '직원',
#  '입및',
#  '전체',
#  '액세서리',
#  '타운',
#  '슬레',
#  '재경',
#  '파견',
#  '마케터',
#  '부서장',
#  '전국',
#  '품평',
#  '발굴',
#  '시계',
#  '자격증',
#  '제품',
#  '테크니컬',
#  '실실',
#  '항공',
#  '능력',
#  '활용',
#  '출고',
#  '애니메이션',
#  '시스템',
#  '전기',
#  '쥬얼리',
#  '결산',
#  '창고',
#  '머처',
#  '실무',
#  '샘플링',
#  '요가복',
#  '신문',
#  '재및',
#  '데이터',
#  '유치원교사',
#  '열성',
#  '재생산',
#  '성인',
#  '개편',
#  '밸류',
#  '참신',
#  '브랜드전략',
#  '보건',
#  '직수입',
#  '혁신',
#  '부띠',
#  '전자통신',
#  '경매',
#  '입찰',
#  '향수',
#  '웹마스터',
#  '한문',
#  '브래드',
#  '외환',
#  '니트웨어',
#  '해운',
#  '예체능',
#  '도서관',
#  '홈페이지',
#  '신제품',
#  '국내외',
#  '이포',
#  '능통',
#  '아티스트',
#  '트및',
#  '일어',
#  '남녀',
#  '메이크업',
#  '기장',
#  '회로',
#  '다시',
#  '신고',
#  '어시스트',
#  '대외',
#  '빈폴',
#  '정밀',
#  '부속',
#  '리조트',
#  '금용',
#  '구조공학',
#  '아이',
#  '무선통신',
#  '수강생',
#  '이태리어',
#  '퍼스',
#  '인쇄',
#  '견적',
#  '파워포인트',
#  '현장',
#  '중심',
#  '공모전',
#  '부지',
#  '정비',
#  '부서',
#  '스웨',
#  '컨템포러리',
#  '중개사',
#  '복리',
#  '공인',
#  '및머',
#  '인수합병',
#  '전공자',
#  '오브',
#  '콘텐츠',
#  '지식',
#  '광학',
#  '운전',
#  '후생',
#  '이태리',
#  '호스트',
#  '겸비',
#  '편집디자이너',
#  '머쳔다이져',
#  '프런트',
#  '스키',
#  '학위',
#  '육상',
#  '프로그래머',
#  '론칭',
#  '총지배인',
#  '해외진출',
#  '출입',
#  '재수',
#  '휘트니',
#  '이전',
#  '이동통신',
#  '번의',
#  '베타테스트',
#  '석등',
#  '용기',
#  '지시',
#  '부분',
#  '성공',
#  '샵마',
#  '온라인마케팅',
#  '정보디자인',
#  '에너지',
#  '일러스트레이터',
#  '입점',
#  '소프트웨어',
#  '패션쇼',
#  '및바잉',
#  '부부',
#  '증권',
#  '생생',
#  '공임',
#  '드레이핑',
#  '멀티',
#  '편지',
#  '활발',
#  '스레이',
#  '장나영',
#  '디렉팅',
#  '시각디자인',
#  '의류사',
#  '엔지니어',
#  '여행사',
#  '교통광고',
#  '프리젠테이션',
#  '온라인광고',
#  '특기',
#  '의원',
#  '구인',
#  '이커머스',
#  '은행',
#  '배차',
#  '실내',
#  '캐시미어',
#  '수영',
#  '체력',
#  '수발',
#  '카피라이터',
#  '안내',
#  '정보보호',
#  '더존',
#  '옥외광고',
#  '예측',
#  '피티',
#  '납품',
#  '이동',
#  '종이',
#  '수영복',
#  '입력',
#  '등부',
#  '소비자보호',
#  '컴퓨터그래픽스',
#  '창의력',
#  '카탈로그',
#  '법무',
#  '제조',
#  '석유화학',
#  '전기회로',
#  '단사',
#  '공장장',
#  '모델하우스',
#  '웹서비스',
#  '패키지디자인',
#  '매부',
#  '캐드',
#  '편직',
#  '사회',
#  '복지사',
#  '주재',
#  '매출채권',
#  '대기',
#  '마스',
#  '복막',
#  '이상',
#  '성우',
#  '싱처',
#  '프론트',
#  '투입',
#  '소품',
#  '상설점',
#  '상업',
#  '인테리어디자이너',
#  '논술',
#  '컨설턴트',
#  '차장',
#  '디다',
#  '보도자료',
#  '상푹',
#  '정보검색',
#  '카지노',
#  '애견',
#  '레이',
#  '홍보물',
#  '서울',
#  '미국',
#  '통신',
#  '객실',
#  '단가',
#  '에지',
#  '출납',
#  '생상',
#  '연예인',
#  '엑세스',
#  '협찬',
#  '럭셔리',
#  '미화',
#  '환편',
#  '끈기',
#  '학과',
#  '여행',
#  '소싱',
#  '경기',
#  '룩북',
#  '과학',
#  '웹디자인',
#  '화공',
#  '취재',
#  '작성',
#  '뷰티',
#  '회원',
#  '담배',
#  '한국어',
#  '책임자',
#  '수행',
#  '작가',
#  '시나리오',
#  '언론',
#  '라이센스',
#  '위험',
#  '도시',
#  '브이',
#  '워드',
#  '숙경',
#  '금액',
#  '트렌디',
#  '오픈마켓',
#  '선적',
#  '염색',
#  '패기',
#  '소프트',
#  '사보',
#  '보증',
#  '및입',
#  '콘도',
#  '직사',
#  '사무관리',
#  '목표',
#  '카메라',
#  '남여',
#  '패션사진',
#  '교육세',
#  '거주',
#  '격증',
#  '전자공학',
#  '서핑',
#  '컨버터',
#  '공예',
#  '플레그',
#  '기타',
#  '아웃',
#  '테리',
#  '어스',
#  '컨설턴드',
#  '재단',
#  '시공',
#  '행정학',
#  '베트남',
#  '의약',
#  '석사',
#  '스퐃',
#  '무역영어',
#  '벤처캐피탈',
#  '사서',
#  '바이럴',
#  '일러스트레이션',
#  '훈련',
#  '공무',
#  '한글',
#  '인복',
#  '입부',
#  '메이커',
#  '프리랜서',
#  '레깅스',
#  '튜닝',
#  '참가',
#  '매입',
#  '육성',
#  '센터',
#  '감정평가',
#  '과외',
#  '감리',
#  '연말정산',
#  '기본',
#  '소통',
#  '창의',
#  '운영자',
#  '신문기자',
#  '유소',
#  '한복',
#  '중간',
#  '공무원',
#  '웨딩드레스',
#  '레이스',
#  '및비딩',
#  '아트디렉터',
#  '학생복',
#  '서치',
#  '베이',
#  '구입',
#  '사진기',
#  '외국',
#  '수질',
#  '피트니스',
#  '디지털',
#  '중고',
#  '포장디자인',
#  '건강',
#  '프로젝트',
#  '매뉴얼',
#  '배송',
#  '슈퍼',
#  '리노',
#  '섬직',
#  '저축은행',
#  '직지',
#  '종합병원',
#  '강의',
#  '양복',
#  '맞춤',
#  '컴퓨터그래픽',
#  '봉제',
#  '사용',
#  '제화',
#  '벽지',
#  '스타킹',
#  '번역',
#  '애니메',
#  '임대',
#  '대졸',
#  '라인',
#  '라이선스',
#  '지배인',
#  '수학',
#  '팅트',
#  '아르바이트',
#  '만화',
#  '이사',
#  '인테리어디자인',
#  '긍정',
#  '외식',
#  '프랑스어',
#  '아디',
#  '필기',
#  '합격',
#  '광리',
#  '장지원',
#  '머쳔다이저',
#  '컬설',
#  '천세',
#  '채권',
#  '센싱',
#  '인적',
#  '페럴',
#  '상설',
#  '리셉션',
#  '화학',
#  '취미',
#  '수주',
#  '컬리',
#  '사항',
#  '요업',
#  '네트워크',
#  '그레이',
#  '포워딩',
#  '물품',
#  '교육행정',
#  '모던',
#  '라이',
#  '화섬류',
#  '식스시그마',
#  '캐릭',
#  '최종',
#  '활달',
#  '간이',
#  '성경',
#  '취득',
#  '스니커즈',
#  '직무',
#  '운전기사',
#  '인디자인',
#  '업부',
#  '프리미엄',
#  '하의',
#  '검품',
#  '전자',
#  '의료',
#  '마킹',
#  '모노',
#  '몽상가',
#  '완사입',
#  '양성',
#  '전자회로',
#  '복디',
#  '생활용품',
#  '건물',
#  '스트리트',
#  '생각',
#  '드림위버',
#  '편안함',
#  '로움',
#  '세련',
#  '확인',
#  '보완',
#  '이상지',
#  '원사',
#  '웨딩',
#  '가구',
#  '컨셉',
#  '정유',
#  '신입사원',
#  '전문점',
#  '워터스포츠',
#  '보안',
#  '국어',
#  '나염',
#  '감사',
#  '해상',
#  '빈티',
#  '연구원',
#  '기사',
#  '다운',
#  '카테고리',
#  '음료',
#  '프로세스',
#  '패키지',
#  '도매',
#  '포토',
#  '그래퍼',
#  '불어',
#  '학사',
#  '커뮤니케이션',
#  '상가',
#  '사교',
#  '대형',
#  '리더쉽',
#  '영엽',
#  '근면',
#  '복사',
#  '워싱',
#  '호텔',
#  '고어텍스',
#  '회계사',
#  '소개',
#  '보석',
#  '입시',
#  '방과후',
#  '중개인',
#  '도서',
#  '소비재',
#  '재료',
#  '업종',
#  '솔루션',
#  '부동산경매',
#  '공시',
#  '프랜차이즈',
#  '임베디드',
#  '관리인',
#  '윤기',
#  '데이터베이스',
#  '기계',
#  '확장',
#  '상픔',
#  '출하',
#  '인자',
#  '슈즈구',
#  '벨트',
#  '비품',
#  '포스터',
#  '필드',
#  '상의',
#  '침구',
#  '쉐타',
#  '관리직',
#  '체육',
#  '배분',
#  '교수설계',
#  '스케쥴',
#  '타임',
#  '회의',
#  '브랜딩',
#  '원화',
#  '가드',
#  '배낭',
#  '우먼',
#  '컨벤션',
#  '테일러',
#  '집기',
#  '무역사',
#  '프랑스',
#  '교육사',
#  '보판',
#  '전문직',
#  '사무자동화산업기사',
#  '컨템',
#  '업계',
#  '슈퍼바이저',
#  '도트',
#  '발행',
#  '내부감사',
#  '화보',
#  '라이노',
#  '직기',
#  '지혜',
#  '호텔리어',
#  '시각',
#  '병원',
#  '안녕하십니까',
#  '투자',
#  '파슨스',
#  '동향',
#  '독창',
#  '예술',
#  '선정',
#  '구성',
#  '디자이너잡',
#  '재무회계',
#  '설비',
#  '문화',
#  '텍스프',
#  '배율',
#  '농구',
#  '가격',
#  '협상',
#  '가관',
#  '발광다이오드']

# %%
box_index = (check_vc.index) 
for k in check_vc2:
    res_mer[f'{k}'] = 0  # 초기값 설정
    
for i in range(len(res_mer)):
    j = res_mer['text_keyword'][i]
    for k in range(len(check_vc2)):
        if isinstance(k, str):
            if re.search(check_vc2[k], j) is not None :
                res_mer[f'{k}'][i] = 1
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# ...
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정
# C:\Users\user\AppData\Local\Temp\ipykernel_7756\123111402.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   res_mer[f'{k}'] = 0  # 초기값 설정

# %%
scaler1 = StandardScaler()
res_mer['career_month'] = scaler1.fit_transform(res_mer['career_month'].values.reshape(-1, 1))

# %%
res_mer['degree']=res_mer['degree'].astype('category')                   # 5개의 유니크
res_mer['graduate_date']=res_mer['graduate_date'].astype('category')     # 49개의 유니크
res_mer['job_code_seq1']=res_mer['job_code_seq1'].astype('category')     # 3개의 유니크
res_mer['career_job_code']=res_mer['career_job_code'].astype('category') # 41개의 유니크

# %%
add1 = pd.get_dummies(res_mer['degree'],prefix ='degree',dtype='int') 
add2 = pd.get_dummies(res_mer['graduate_date'],prefix ='graduate',dtype='int') 
add3 = pd.get_dummies(res_mer['job_code_seq1'],prefix ='job_code',dtype='int') 
add4 = pd.get_dummies(res_mer['career_job_code'],prefix ='career_job',dtype='int') 
res_mer = pd.concat([res_mer,add1,add2,add3,add4],axis=1)

# %%
res_mer1=res_mer.drop(['degree','graduate_date','hope_salary','last_salary','job_code_seq1','career_job_code','text_box','text_keyword'],axis=1)

# %%
res_mer1
# Out:
#             career_month  기획  영업  관리  디자인  디자이너  패션  상품  의류  매장  ...  \
# resume_seq                                                       ...
# U00001         -1.092295   0   0   0    0     0   0   0   0   0  ...
# U00002          0.056512   0   0   0    0     0   0   0   0   0  ...
# U00003          0.685995   0   0   0    0     0   0   0   0   0  ...
# U00004         -0.667393   0   0   0    0     0   0   0   0   0  ...
# U00005         -1.092295   0   0   0    0     0   0   0   0   0  ...
# ...                  ...  ..  ..  ..  ...   ...  ..  ..  ..  ..  ...
# U08478         -0.148070   0   0   0    0     0   0   0   0   0  ...
# U08479         -0.163807   0   0   0    0     0   0   0   0   0  ...
# U08480         -1.092295   0   0   0    0     0   0   0   0   0  ...
# U08481         -0.966398   0   0   0    0     0   0   0   0   0  ...
# U08482         -1.092295   0   0   0    0     0   0   0   0   0  ...
#
#             career_job_인터넷서비스;포털;컨텐츠  career_job_자동차;운송장비;조선;항공  \
# resume_seq
# U00001                             0                          0
# U00002                             0                          0
# U00003                             0                          0
# U00004                             0                          0
# U00005                             0                          0
# ...                              ...                        ...
# U08478                             0                          0
# U08479                             0                          0
# U08480                             0                          0
# U08481                             0                          0
# U08482                             0                          0
#
#             career_job_전기;가스;수도;에너지  career_job_전기;전자;통신장비  \
# resume_seq
# U00001                            0                      0
# U00002                            0                      0
# U00003                            0                      0
# U00004                            0                      0
# U00005                            0                      0
# ...                             ...                    ...
# U08478                            0                      0
# U08479                            0                      0
# U08480                            0                      0
# U08481                            0                      0
# U08482                            0                      0
#
#             career_job_철강;금속;비금속;재료  career_job_출판;인쇄;편집;영상  \
# resume_seq
# U00001                            0                       0
# U00002                            0                       0
# U00003                            0                       0
# U00004                            0                       0
# U00005                            0                       0
# ...                             ...                     ...
# U08478                            0                       0
# U08479                            0                       0
# U08480                            0                       0
# U08481                            0                       0
# U08482                            0                       0
#
#             career_job_컴퓨터;사무기기;소비재  career_job_학교;학원;직원훈련(교육서비스)  \
# resume_seq
# U00001                            0                             0
# U00002                            0                             0
# U00003                            0                             0
# U00004                            0                             0
# U00005                            0                             0
# ...                             ...                           ...
# U08478                            0                             0
# U08479                            0                             0
# U08480                            0                             0
# U08481                            0                             0
# U08482                            0                             0
#
#             career_job_호텔;숙박;관광;여행;외식  career_job_화학;고무;플라스틱
# resume_seq
# U00001                              0                      0
# U00002                              0                      0
# U00003                              0                      0
# U00004                              0                      0
# U00005                              0                      0
# ...                               ...                    ...
# U08478                              0                      0
# U08479                              0                      0
# U08480                              0                      0
# U08481                              0                      0
# U08482                              0                      0
#
# [8482 rows x 1062 columns]
